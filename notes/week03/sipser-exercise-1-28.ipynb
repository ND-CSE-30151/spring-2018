# %% [markdown]
# # Solutions to Sipser Exercise 1.28

# %%
from tock import *

# %% [markdown]
# The solutions below show every intermediate step; on a homework or exam, you would only be required to show the final result.

# %%
from_regexp('a (a b b)* | b', display_steps=True)
# Out:
# subexpression: a
# subexpression: a
# subexpression: b
# subexpression: b
# subexpression: a b b
# subexpression: (a b b)*
# subexpression: a (a b b)*
# subexpression: b
# subexpression: a (a b b)*|b

# %%
from_regexp('a a* | (a b) (a b)*', display_steps=True)
# Out:
# subexpression: a
# subexpression: a
# subexpression: a*
# subexpression: a a*
# subexpression: a
# subexpression: b
# subexpression: a
# subexpression: b
# subexpression: a b
# subexpression: (a b)*
# subexpression: a b (a b)*
# subexpression: a a*|a b (a b)*

# %%
from_regexp('(a | b b*) a a* b b*', display_steps=True)
# Out:
# subexpression: a
# subexpression: b
# subexpression: b
# subexpression: b*
# subexpression: b b*
# subexpression: a|b b*
# subexpression: a
# subexpression: a
# subexpression: a*
# subexpression: b
# subexpression: b
# subexpression: b*
# subexpression: (a|b b*) a a* b b*
